# %% [markdown]
# TEIS Referral Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Explore the data

# %%
teis_mon = pd.read_csv('../data/teis_monthly.csv')
teis_mon.head( )
# Out:
#   POE  Child ID        DOB County Name    County SES   Child Phase Active  \
# 0  ET    403339   8/9/2014      Blount  Transitional   Eligibility      A
# 1  FT    404085  7/31/2013      Unicoi       At-Risk  Notification      I
# 2  FT    403623   2/5/2016    Sullivan  Transitional   Eligibility      A
# 3  FT    404157  12/6/2015    Sullivan  Transitional          IFSP      A
# 4  FT    404154  4/18/2015     Hawkins       At-Risk          IFSP      A
#
#             Service Coordinator Notification/ Referral Date  \
# 0                  Kristi Borer                    7/1/2016
# 1  Jennifer Terranera - 45 days                    7/1/2016
# 2                   Amy Talbert                    7/1/2016
# 3                Candice Cradic                    7/1/2016
# 4                Kathy Jeffries                    7/1/2016
#
#   Parent Consent Date  ... Service Coordinator Counter Fiscal Year.1  \
# 0              7/1/16  ...                           1          2016
# ...

# %%
teis_mon.tail( )
# Out:
#        POE  Child ID        DOB County Name    County SES  Child Phase Active  \
# 113251  UC    528759   4/7/2021      Sumner   Competitive   Evaluation      A
# 113252  UC    528534  3/13/2022      Sumner   Competitive         IFSP      A
# 113253  UC    528430   1/5/2022  Cumberland  Transitional  Eligibility      A
# 113254  UC    528253  9/12/2020      Sumner   Competitive         IFSP      A
# 113255  UC    528535   2/8/2022       Smith  Transitional   Evaluation      A
#
#        Service Coordinator Notification/ Referral Date Parent Consent Date  \
# 113251   Sherry Roberts-DS                   5/16/2022           5/26/2022
# 113252         Robyn Hogan                   5/11/2022           5/23/2022
# 113253          Lisa Davis                   5/10/2022           5/18/2022
# 113254          Taylor Lee                    5/6/2022           5/11/2022
# 113255   Sherry Roberts-DS                   5/11/2022           5/27/2022
#
# ...

# %%
teis_mon.shape
# Out:
# (113256, 34)
