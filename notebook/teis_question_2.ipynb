# %%
import pandas as pd   
import numpy as np
import matplotlib.pyplot as plt  
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Question 2
# A referral is considered a "successful" referral if it results in an Individualized Family Service Plan (IFSP).
#
# Are there referral sources that have had higher rates of successful referrals?
#
# You can determine whether a referral was successful by looking at whether the Initial IFSP Date
# column is filled in or whether the Child Phase column is equal to IFSP.

# %%
teis_final = pd.read_csv('../data/teis_final_data.csv')

teis_final
# Out:
#         Child ID Notification Date Fiscal Year Notification Month Tenn Region  \
# 0         104085        2018-01-20   2017-2018                Jan      Middle
# 1         350065        2016-08-17   2016-2017                Aug      Middle
# 2         351755        2016-07-12   2016-2017                Jul     Western
# 3         353800        2016-09-14   2016-2017                Sep     Eastern
# 4         353805        2016-08-05   2016-2017                Aug      Middle
# ...          ...               ...         ...                ...         ...
# 115519    531592        2022-07-01         NaN                NaN         NaN
# 115520    531593        2022-07-01         NaN                NaN         NaN
# 115521    531594        2022-07-01         NaN                NaN         NaN
# 115522    531595        2022-07-01         NaN                NaN         NaN
# 115523    531596        2022-07-01         NaN                NaN         NaN
#
#         Fiscal Year.1   third_DOB  Late Referral  Qtr POE  ...  \
# 0              2017.0  2010-07-07            1.0  3.0  GN  ...
# 1              2016.0  2016-10-15            1.0  1.0  UC  ...
# 2              2016.0  2016-11-13            NaN  1.0  NW  ...
# 3              2016.0  2016-10-01            1.0  1.0  FT  ...
# 4              2016.0  2016-12-04            NaN  1.0  UC  ...
# ...               ...         ...            ...  ...  ..  ...
# 115519            NaN         NaN            NaN  NaN  GN  ...
# 115520            NaN         NaN            NaN  NaN  GN  ...
# 115521            NaN         NaN            NaN  NaN  GN  ...
# 115522            NaN         NaN            NaN  NaN  GN  ...
# 115523            NaN         NaN            NaN  NaN  SC  ...
#
#                  Service Coordinator Parent Consent Initial Eligibility  \
# 0                                NaN            NaN                 NaN
# 1                    Steven Scarlett            NaN                 NaN
# 2                          Rene Bard     2016-07-12          Ineligible
# 3       Jennifer Terranera - 45 days            NaN                 NaN
# 4                         Anna Bolin     2016-08-15            Eligible
# ...                              ...            ...                 ...
# 115519                   Kim Correll            NaN                 NaN
# 115520                   Kim Correll            NaN                 NaN
# 115521                   Kim Correll            NaN                 NaN
# 115522                   Kim Correll            NaN                 NaN
# 115523                   Kim Correll            NaN                 NaN
#
#        Initial Eligibility Date Initial IFSP Date Latest IFSP  \
# 0                           NaN               NaN         NaN
# 1                           NaN               NaN         NaN
# 2                     8/25/2016               NaN         NaN
# 3                           NaN               NaN         NaN
# 4                     10/5/2016        10/10/2016         NaN
# ...                         ...               ...         ...
# 115519                      NaN               NaN         NaN
# 115520                      NaN               NaN         NaN
# 115521                      NaN               NaN         NaN
# 115522                      NaN               NaN         NaN
# 115523                      NaN               NaN         NaN
#
#                                     Exit Reason   Exit Date  \
# 0                             Unable to contact  2010-01-25
# 1                             Unable to contact  2016-08-31
# 2                         Ineligible for Part C  2016-08-25
# 3                    Referral less than 45 days  2016-09-15
# 4       618 - Part B eligibility not determined  2016-12-03
# ...                                         ...         ...
# 115519                                      NaN         NaN
# 115520                                      NaN         NaN
# 115521                                      NaN         NaN
# 115522                                      NaN         NaN
# 115523                                      NaN         NaN
#
#          Referral Source Type Name  Year
# 0                              DCS  2018
# 1                              PCP  2016
# 2                           Parent  2016
# 3                           Parent  2016
# 4                  Dept. of Health  2016
# ...                            ...   ...
# 115519                         PCP  2022
# 115520                         PCP  2022
# 115521  Other Health Care Provider  2022
# 115522                    Hospital  2022
# 115523                         PCP  2022
#
# [115524 rows x 25 columns]

# %%
teis_final['Successful'] = ((teis_final['Child Phase'] == "IFSP") | (teis_final['Initial IFSP Date'].notnull()))

# %%
teis_final.head()
# Out:
#    Child ID Notification Date Fiscal Year Notification Month Tenn Region  \
# 0    104085        2018-01-20   2017-2018                Jan      Middle
# 1    350065        2016-08-17   2016-2017                Aug      Middle
# 2    351755        2016-07-12   2016-2017                Jul     Western
# 3    353800        2016-09-14   2016-2017                Sep     Eastern
# 4    353805        2016-08-05   2016-2017                Aug      Middle
#
#    Fiscal Year.1   third_DOB  Late Referral  Qtr POE  ... Parent Consent  \
# 0         2017.0  2010-07-07            1.0  3.0  GN  ...            NaN
# 1         2016.0  2016-10-15            1.0  1.0  UC  ...            NaN
# 2         2016.0  2016-11-13            NaN  1.0  NW  ...     2016-07-12
# 3         2016.0  2016-10-01            1.0  1.0  FT  ...            NaN
# 4         2016.0  2016-12-04            NaN  1.0  UC  ...     2016-08-15
#
#   Initial Eligibility Initial Eligibility Date Initial IFSP Date Latest IFSP  \
# 0                 NaN                      NaN               NaN         NaN
# 1                 NaN                      NaN               NaN         NaN
# 2          Ineligible                8/25/2016               NaN         NaN
# 3                 NaN                      NaN               NaN         NaN
# 4            Eligible                10/5/2016        10/10/2016         NaN
#
#                                Exit Reason   Exit Date  \
# 0                        Unable to contact  2010-01-25
# 1                        Unable to contact  2016-08-31
# 2                    Ineligible for Part C  2016-08-25
# 3               Referral less than 45 days  2016-09-15
# 4  618 - Part B eligibility not determined  2016-12-03
#
#   Referral Source Type Name  Year Successful
# 0                       DCS  2018      False
# 1                       PCP  2016      False
# 2                    Parent  2016      False
# 3                    Parent  2016      False
# 4           Dept. of Health  2016       True
#
# [5 rows x 26 columns]

# %%
total_referrals = teis_final.groupby(['Referral Source Type Name'])['Successful'].count()
total_referrals
# Out:
# Referral Source Type Name
# CAPTA                                2
# Child Care provider                434
# Community/Child Find Activity      386
# DCS                              25721
# DHS                                 13
# DMRS                                 1
# Dept. of Health                   3675
# EIRA                               351
# Early Head Start/Head Start       1025
# Family and Friends                 516
# Foster Parent                      421
# Hospital                          7292
# LEA                                 16
# NHS                                222
# NICU                              3275
# OT                                  86
# Other                             2612
# Other Health Care Provider        2326
# PCP                              43899
# PICU                                26
# PT                                 623
# Parent                           21944
# Speech Therapist                   654
# TIPS                                 4
# Name: Successful, dtype: int64

# %%
total_referrals_successful = teis_final.groupby(['Referral Source Type Name'])['Successful'].sum()
total_referrals_successful
# Out:
# Referral Source Type Name
# CAPTA                                0
# Child Care provider                179
# Community/Child Find Activity      155
# DCS                               4510
# DHS                                  3
# DMRS                                 1
# Dept. of Health                   1375
# EIRA                               169
# Early Head Start/Head Start        423
# Family and Friends                 274
# Foster Parent                      262
# Hospital                          2916
# LEA                                  6
# NHS                                 69
# NICU                              1158
# OT                                  44
# Other                             1184
# Other Health Care Provider        1146
# PCP                              18264
# PICU                                15
# PT                                 375
# Parent                           12595
# Speech Therapist                   395
# TIPS                                 2
# Name: Successful, dtype: int64

# %%
tot_ref = pd.merge(total_referrals, total_referrals_successful, on='Referral Source Type Name', how='left').rename(columns = {'Successful_x' : 'Total Referrals', 'Successful_y' : 'Total Successful Referrals'})
tot_ref.reset_index()
# Out:
#         Referral Source Type Name  Total Referrals  Total Successful Referrals
# 0                           CAPTA                2                           0
# 1             Child Care provider              434                         179
# 2   Community/Child Find Activity              386                         155
# 3                             DCS            25721                        4510
# 4                             DHS               13                           3
# 5                            DMRS                1                           1
# 6                 Dept. of Health             3675                        1375
# 7                            EIRA              351                         169
# 8     Early Head Start/Head Start             1025                         423
# 9              Family and Friends              516                         274
# 10                  Foster Parent              421                         262
# 11                       Hospital             7292                        2916
# 12                            LEA               16                           6
# 13                            NHS              222                          69
# 14                           NICU             3275                        1158
# 15                             OT               86                          44
# 16                          Other             2612                        1184
# 17     Other Health Care Provider             2326                        1146
# 18                            PCP            43899                       18264
# 19                           PICU               26                          15
# 20                             PT              623                         375
# 21                         Parent            21944                       12595
# 22               Speech Therapist              654                         395
# 23                           TIPS                4                           2

# %%
tot_ref['Percentage Success'] = ((tot_ref['Total Successful Referrals']/tot_ref['Total Referrals']) * 100).round(decimals=2)
tot_ref.reset_index()
tot_ref.columns
# Out:
# Index(['Total Referrals', 'Total Successful Referrals', 'Percentage Success'], dtype='object')

# %%
tot_ref=tot_ref.reset_index()

# %%
tot_ref=tot_ref.sort_values(by='Percentage Success', ascending = False)

# %%
tot_ref=tot_ref[tot_ref['Total Referrals'] > 100]

# %%
fig, ax = plt.subplots(figsize =(15, 10))
 
# Horizontal Bar Plot
ax.barh(tot_ref['Referral Source Type Name'], tot_ref['Percentage Success'], color='#1E6091')
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 12, fontweight ='normal',
             color ='black')
 
# Add Plot Title
#ax.set_title('Successful Referral Percentage By Provider Source',
             #loc ='left', )

# Add Text watermark
#fig.text(0.9, 0.15, 'Jeeteshgavande30', fontsize = 12,
#         color ='black', ha ='right', va ='bottom',
#         alpha = 0.7)
#plt.text(40,16,'Chart does not include resources with less than 100 referrals')
# Show Plot
plt.show()

#fig.savefig('../data/successful_referral_percentage_by_provider_source.png', dpi='figure', format='png', metadata=None,
 #       bbox_inches='tight', pad_inches=0.1,
  #      facecolor='auto', edgecolor='auto', transparent=True,
   #     backend=None
    #   )

# %%
tot_ref2=tot_ref.sort_values(by='Total Referrals', ascending = False)
tot_ref2
# Out:
#         Referral Source Type Name  Total Referrals  \
# 18                            PCP            43899
# 3                             DCS            25721
# 21                         Parent            21944
# 11                       Hospital             7292
# 6                 Dept. of Health             3675
# 14                           NICU             3275
# 16                          Other             2612
# 17     Other Health Care Provider             2326
# 8     Early Head Start/Head Start             1025
# 22               Speech Therapist              654
# 20                             PT              623
# 9              Family and Friends              516
# 1             Child Care provider              434
# 10                  Foster Parent              421
# 2   Community/Child Find Activity              386
# 7                            EIRA              351
# 13                            NHS              222
#
#     Total Successful Referrals  Percentage Success
# 18                       18264               41.60
# 3                         4510               17.53
# 21                       12595               57.40
# 11                        2916               39.99
# 6                         1375               37.41
# 14                        1158               35.36
# 16                        1184               45.33
# 17                        1146               49.27
# 8                          423               41.27
# 22                         395               60.40
# 20                         375               60.19
# 9                          274               53.10
# 1                          179               41.24
# 10                         262               62.23
# 2                          155               40.16
# 7                          169               48.15
# 13                          69               31.08

# %%
# Figure Size
fig, ax = plt.subplots(figsize =(15, 10))
 
# Horizontal Bar Plot
ax.barh(tot_ref2['Referral Source Type Name'], tot_ref2['Total Referrals'], color = '#1E6091')
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(b = True, color ='gray',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for counter, i in enumerate(ax.patches):
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             #str(round((i.get_width()), 2)),
             str(tot_ref2['Percentage Success'].values[counter]),
             fontsize = 12, fontweight ='normal',
             color ='black')
 
# Add Plot Title
#ax.set_title('Total Referrals with Success Percentage by Provider',
 #            loc ='left', )

#plt.text(27000,16,'Chart does not include resources with less than 100 referrals')
# S
# Show Plot
plt.show()

fig.savefig('../data/total_referrals_with_success_percentage_by_provider.png', dpi='figure', format='png', metadata=None,
        bbox_inches='tight', pad_inches=0.1,
        facecolor='auto', edgecolor='auto', transparent=True,
        backend=None
       )

# %%
tot_ref.sort_values(by = 'Total Successful Referrals').plot(x='Referral Source Type Name',
                y = ['Total Referrals', 'Total Successful Referrals'], kind = 'barh', figsize = (15,10), width = .9, color = ['#1E6091', '#76C893'])
#plt.text(10,6,'  Less than 100 total referrals')
plt.ylabel(None)
plt.legend(loc='center')

#plt.text(27000,0,'Chart does not include resources with less than 100 referrals')

plt.savefig('../data/total_vs_successful.png', dpi='figure', format='png', metadata=None,
        bbox_inches='tight', pad_inches=0.1,
        facecolor='auto', edgecolor='auto', transparent=True,
        backend=None
       )
